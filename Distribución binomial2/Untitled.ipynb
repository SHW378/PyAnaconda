# %% [markdown]
# Nombre: César Alberto Cázares Chaván
# Fecha: 25/09/2025

# %%
import matplotlib.pyplot as plt
from scipy.stats import binom

# %%
def graficarDistribucionBinomial(tope, pro):
    valores=[]
    probabilidades=[]
    for i in range(0, tope+1,1):
        valores.append(i)
        probabilidades.append(binom.pmf(n=tope,k=i,p=pro))
    return valores, probabilidades

# %%
#Graficar función
valores, probabilidades=graficarDistribucionBinomial(10,0.5)
plt.scatter(valores, probabilidades)
plt.ylabel("p(X)")
plt.xlabel("x")
plt.show
print("E(X):", 10*.5)
print("VAR(X)", 10*.5*.5)
print("STD(X)", (10*.5*.5)**(1/2))
# Out:
# E(X): 5.0
# VAR(X) 2.5
# STD(X) 1.5811388300841898

# %%
#Graficar función
valores, probabilidades=graficarDistribucionBinomial(15,0.1)
plt.scatter(valores, probabilidades)
plt.ylabel("p(X)")
plt.xlabel("x")
plt.show
print("E(X):", 15*.1)
print("VAR(X)", 15*.1*.9)
print("STD(X)", (15*.1*.9)**(1/2))
# Out:
# E(X): 1.5
# VAR(X) 1.35
# STD(X) 1.161895003862225
